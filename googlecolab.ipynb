# %% [markdown]
# <a href="https://colab.research.google.com/github/mmilyas245-dot/numpy_pandas_exercise26/blob/main/googlecolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world! a code from google colab")
# Out:
# hello world! a code from google colab

# %%
num=int(input("enter a number: "))
if num>0:
  print("number is positive!")
else:
  print("number is negative")
# Out:
# enter a number: -111
# number is negative
